# %% [markdown]
# # If else statements in Python

# %%
x=50
y=100
if x>y:
    print('x is greater than y')
else:
    print('Out')

# %%
x=50
y=100
if x>y:
    print('x is greater than y')
elif y>x:
    print('y is greater than x')
    print('data science')
    if x!=y:
        print('Not equal')
    if x==y:
        print('Equal')
else:
    print('Out')

# %%
num = float(input('Enter any number: '))

if num % 2 ==0:
    if num % 5 ==0:
        print(num, 'Divisible bt 5 and 2')
    else:
        print('No')
else:
    print('No 2')

# %%
from IPython.display import Image
Image('electricity_bill.png')

# %%
aamount = 0

net_units = float(input('Enter your unit value : '))

if net_units <= 100:
    amonut = 0
    
    
elif net_units > 100 and net_units <= 200:
    amount = (net_units - 100) * 5
    

elif net_units>200:
    amount = ((net_units - 200) *10) + 500

print('amount is ',amount)
# Out:
# Enter your unit value : 350
# amount is  2000.0

# %%
from IPython.display import Image
Image('problem.PNG')

# %% [markdown]
# # problem_1

# %%
lenth =float(input('Enter a length: '))
breadth = float(input('Enter a breadth: '))

if lenth == breadth:
    print('Square')
    
else:
    print('Not')
# Out:
# Enter a length: 10
# Enter a breadth: 10
# Square

# %% [markdown]
# # problem_2

# %%
x = float(input("Enter x value: "))
y = float(input("Enter y value: "))
z = float(input("Enter z value: "))

if x>y and x>z:
    print("x is greater than y,z")
elif y>x and y>z:
    print("y is greater than x,z")
else:
    print("z is greater than x,y")
# Out:
# Enter x value: 10
# Enter y value: 20
# Enter z value: 15
# y is greater than x,z

# %% [markdown]
# # problem_4

# %%
held = int(input('Number of classese held :'))
attended = int(input('Number of classes attended: '))

attended_ratio = (attended/held) * 100
# Out:
# Number of classese held :20
# Number of classes attended: 15

# %%
attended_ratio
# Out:
# 75.0

# %%
if attended_ratio >=75:
    print('You are allowed')
    
else:
    print('You are not allowed')
# Out:
# You are allowed

# %% [markdown]
# # problem_4

# %%
marks = float(input('Enter your marks: '))

if marks <25:
    print('You are Genius like me:')
    
elif marks>=25 and marks <=44:
    print('E Grade, pass krco mama! You also tene tune Genius!')

elif marks>=45 and marks <=49:
    print('D Grade')
    
elif marks>=50 and marks <=59:
    print('c Grade')
    
elif marks>=60 and marks <=69:
    print('B Grade')
    
elif marks>=80 and marks <=89:
    print('A Grade')
    
else:
    print('You are a loser!!!')
# Out:
# Enter your marks: 90
# You are a loser!!!
